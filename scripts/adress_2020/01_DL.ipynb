# %%
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 11
#       7 test_dir = r"C:\Users\Lenovo\Desktop\IC\[99] ADRESS-20 Database DL\test"
#       9 # Replace `"your_image_column_name"` and `"your_label_column_name"` with the actual columns
#      10 # in your CSV files
# ---> 11 (control_labels, control_data) = vis.preprocess_csv(
#      12     control_dir,
#      13     x_col="your_image_column_name",
#      14     y_col="your_label_column_name",
#      15     suffix=".csv",
#      16     # Specify the output CSV file for control data
#      17     csv_out="preprocessed_control.csv"
#      18 )
#      20 trn_control, val_control, preproc_control = vis.images_from_csv(
#      21     control_data,
#      22     "image_name",
#    (...)
#      26     data_aug=vis.get_data_aug(horizontal_flip=True, vertical_flip=True)
#      27 )
# ...
